# %%
# !pip install google-generativeai

# %%
import google.generativeai as genai

my_api_key = 'AIzaSyDWXF4luhWgxfAArlgk7_ybNhgz2etL9t0'
genai.configure(api_key=my_api_key)
model = genai.GenerativeModel("gemini-1.5-pro")
# model = genai.GenerativeModel("text-embedding-004")

# %%
# question = "What is the capital of France?"
# choices = "A) London B) Paris C) Rome D) Madrid"
# prompt = f"Question: {question}\nChoices: {choices}\nGive me a very subtle one line hint:"

import google.generativeai as genai

my_api_key = 'AIzaSyDWXF4luhWgxfAArlgk7_ybNhgz2etL9t0'
genai.configure(api_key=my_api_key)
model = genai.GenerativeModel("gemini-1.5-pro")
# model = genai.GenerativeModel("text-embedding-004")

prompt = 'hello'

response = model.generate_content(prompt)
print(response.text)
# Out:
# Hello! How can I help you today?

# %%
import google.generativeai as genai
import pandas as pd
import json

# Configure API key
my_api_key = 'AIzaSyDWXF4luhWgxfAArlgk7_ybNhgz2etL9t0'
genai.configure(api_key=my_api_key)
model = genai.GenerativeModel("gemini-1.5-flash")

# Input JSON data
questions_data = [
    {'question': 'What is the capital of India?', 'options': {'A': 'Delhi', 'B': 'Guwahati', 'C': 'Pune', 'D': 'Bihar'}, 'correctAnswer': 'Delhi'},
    {'question': 'What is a historical monument located in Delhi?', 'options': {'A': 'Sanchi Stupa', 'B': 'Rang Ghar', 'C': 'Red Fort', 'D': 'Kamakhya Temple'}, 'correctAnswer': 'Red Fort'},
    {'question': 'Which among the following is an Union Territory?', 'options': {'A': 'Assam', 'B': 'Delhi', 'C': 'Rajasthan', 'D': 'J&K'}, 'correctAnswer': 'Delhi'}
]

# Lists to store modified questions and options for each question
modified_questions = []
modified_options = []

# Process each question and options separately
for item in questions_data:
    question = item['question']
    options = item['options']
    
    # Generate modified question
    question_prompt = f"Question: {question}\nGive me a very subtle one line hint:"
    question_response = model.generate_content(question_prompt)
    modified_question = question_response.text.strip()

    # Generate modified options
    options_prompt = f"Choices: {', '.join([f'{key}) {value}' for key, value in options.items()])}\nGive me modified options based on these:"
    options_response = model.generate_content(options_prompt)
    
    # Parse modified options from response (assuming response gives each option on a new line)
    modified_option_lines = options_response.text.strip().split('\n')
    modified_option_dict = {line[0]: line[3:].strip() for line in modified_option_lines if len(line) > 2 and line[1] == ')'}
    
    # Append results to lists
    modified_questions.append(modified_question)
    modified_options.append(modified_option_dict)

# Create a DataFrame to store results
df = pd.DataFrame({
    'original_question': [item['question'] for item in questions_data],
    'modified_question': modified_questions,
    'original_options': [item['options'] for item in questions_data],
    'modified_options': modified_options
})

# Create a list to store the modified questions in the desired format
modified_questions_data = []

# Loop through the DataFrame and format the data into the required structure
for index, row in df.iterrows():
    correct_answer_key = next((key for key, value in row['original_options'].items() if value == row['modified_options'][row['correctAnswer']]), None)
    
    modified_questions_data.append({
        'question': row['modified_question'],  # Use the modified question
        'options': row['modified_options'],    # Use the modified options
        'correctAnswer': row['modified_options'].get(correct_answer_key)  # Adjusted to reflect the modified options
    })

# Convert to JSON format
modified_questions_json = json.dumps(modified_questions_data, indent=4)

# Print the JSON output
print(modified_questions_json)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/python_venv/ML/lib64/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'correctAnswer'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 56
# ...

# %%
import google.generativeai as genai
import pandas as pd
import json

# Configure API key
my_api_key = 'AIzaSyDWXF4luhWgxfAArlgk7_ybNhgz2etL9t0'  # Replace with your actual API key
genai.configure(api_key=my_api_key)
model = genai.GenerativeModel("gemini-1.5-flash")

# Input JSON data
questions_data = [
    {'question': 'What is the capital of India?', 'options': {'A': 'Delhi', 'B': 'Guwahati', 'C': 'Pune', 'D': 'Bihar'}, 'correctAnswer': 'Delhi'},
    {'question': 'What is a historical monument located in Delhi?', 'options': {'A': 'Sanchi Stupa', 'B': 'Rang Ghar', 'C': 'Red Fort', 'D': 'Kamakhya Temple'}, 'correctAnswer': 'Red Fort'},
    {'question': 'Which among the following is an Union Territory?', 'options': {'A': 'Assam', 'B': 'Delhi', 'C': 'Rajasthan', 'D': 'J&K'}, 'correctAnswer': 'Delhi'}
]

# Lists to store modified questions and options for each question
modified_questions = []
modified_options = []

# Process each question and options separately
for item in questions_data:
    question = item['question']
    options = item['options']
    correct_answer = item.get('correctAnswer')  # Use get to avoid KeyError
    
    # Generate modified question
    question_prompt = f"Question: {question}\nGive me a very subtle one line hint:"
    question_response = model.generate_content(question_prompt)
    modified_question = question_response.text.strip()

    # Generate modified options
    options_prompt = f"Choices: {', '.join([f'{key}) {value}' for key, value in options.items()])}\nGive me modified options based on these:"
    options_response = model.generate_content(options_prompt)
    
    # Parse modified options from response (assuming response gives each option on a new line)
    modified_option_lines = options_response.text.strip().split('\n')
    modified_option_dict = {line[0]: line[3:].strip() for line in modified_option_lines if len(line) > 2 and line[1] == ')'}
    
    # Append results to lists
    modified_questions.append(modified_question)
    modified_options.append(modified_option_dict)

# Create a DataFrame to store results
df = pd.DataFrame({
    'original_question': [item['question'] for item in questions_data],
    'modified_question': modified_questions,
    'original_options': [item['options'] for item in questions_data],
    'modified_options': modified_options
})

# Create a list to store the modified questions in the desired format
modified_questions_data = []

# Loop through the DataFrame and format the data into the required structure
for index, row in df.iterrows():
    # Check for original correct answer key in modified options
    correct_answer_key = None
    for key, value in row['original_options'].items():
        if value == row['modified_options'].get(key):  # Check against modified options
            correct_answer_key = key
            break
    
    modified_questions_data.append({
        'question': row['modified_question'],  # Use the modified question
        'options': row['modified_options'],    # Use the modified options
        'correctAnswer': correct_answer_key if correct_answer_key else None  # Handle missing correctAnswer
    })

# Convert to JSON format
modified_questions_json = json.dumps(modified_questions_data, indent=4)

# Print the JSON output
print(modified_questions_json)
# Out:
# [
#     {
#         "question": "The answer lies on the banks of the Yamuna River.",
#         "options": {},
#         "correctAnswer": null
#     },
#     {
#         "question": "This monument's name is a reminder of a powerful emperor.",
#         "options": {},
#         "correctAnswer": null
#     },
#     {
#         "question": "Think about a place known for its beautiful beaches and backwaters.",
#         "options": {},
#         "correctAnswer": null
#     }
# ]
